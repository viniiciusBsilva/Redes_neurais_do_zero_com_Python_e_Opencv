# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img1 = np.array([[0,255,0],
                [0,255,0],
                [0,255,0]])

# %%
img = cv2.imwrite("imagem1.jpg",img1)

# %%
plt.imshow(img1)

# %%
img2 = np.array([[0,0,0],
                [255,255,255],
                [0,0,0]])

# %%
plt.imshow(img2)

# %%
cv2.imwrite("imagem2.jpg", img2)
# Out:
# True
